# %% [markdown]
# #                             Data Science Miniproject
#
# ## _Abhishek_Sutar
#
# ### Use the following covid_vaccine_statewise.csv dataset and perform following analytics on the
# ### given dataset https://www.kaggle.com/sudalairajkumar/covid19-inindia?select=covid_vaccine_statewise.csv

# %% [markdown]
# ## a. Describe the dataset

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Reading dataset
df = pd.read_csv(r"archive\covid_vaccine_statewise.csv")

#Use '.head()' to see the first rows of the dataset
df.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %%
#Use '.tail()' to see the last rows of the dataset
df.tail()
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 7840                      NaN                       NaN
# 7841                      NaN                       NaN
# 7842                      NaN                       NaN
# 7843                      NaN                       NaN
# 7844                      NaN                       NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 7840                        NaN                          NaN
# ...

# %%
# a) Describe the dataset

df.describe()
# Out:
#        Total Doses Administered      Sessions        Sites   \
# count              7.621000e+03  7.621000e+03   7621.000000
# mean               9.188171e+06  4.792358e+05   2282.872064
# std                3.746180e+07  1.911511e+06   7275.973730
# min                7.000000e+00  0.000000e+00      0.000000
# 25%                1.356570e+05  6.004000e+03     69.000000
# 50%                8.182020e+05  4.547000e+04    597.000000
# 75%                6.625243e+06  3.428690e+05   1708.000000
# max                5.132284e+08  3.501031e+07  73933.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             7.621000e+03              7.621000e+03
# mean              7.414415e+06              1.773755e+06
# std               2.995209e+07              7.570382e+06
# min               7.000000e+00              0.000000e+00
# 25%               1.166320e+05              1.283100e+04
# 50%               6.614590e+05              1.388180e+05
# ...

# %%
# To print the states data from the Dataset( excluding India)

df.loc[df.State!='India',]
# Out:
#       Updated On                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
# ...          ...                          ...                       ...
# 7840  11/08/2021                  West Bengal                       NaN
# 7841  12/08/2021                  West Bengal                       NaN
# 7842  13/08/2021                  West Bengal                       NaN
# 7843  14/08/2021                  West Bengal                       NaN
# 7844  15/08/2021                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %% [markdown]
# ## b. Number of persons state wise vaccinated for first dose in India

# %%
#Initiating dictionary wherein key is state name and value is first dose administered

my_dict = {'Andaman and Nicobar Islands':216046.0};

#list of states
list=['Maharashtra','Arunachal Pradesh','Assam','Bihar','Mizoram','Chhattisgarh',
      'Dadra and Nagar Haveli and Daman and Diu','Delhi','Goa','Gujarat','Haryana',
      'Himachal Pradesh','Jammu and Kashmir','Jharkhand','Karnataka','Kerala','Uttarakhand',
      'Lakshadweep','Madhya Pradesh','Andhra Pradesh','Manipur','Meghalaya','Chandigarh','Nagaland','Odisha',
      'Puducherry','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Ladakh','West Bengal']
i=0
while i<35:
       
    total=df.loc[df.State==list[i],'First Dose Administered'].max() #----> To get number of first dose vaccinated people of last day of the column for perticular state
    state= list[i]
    my_dict[state]= total
    i+=1
    


print ("{:<50} {:<60}".format('State', 'First_Dose_Administered'))
for k, v in my_dict.items():
    First_Dose_Administered = v
    State=k
    print ("{:<50} {:<60}".format( k,First_Dose_Administered))
# Out:
# State                                              First_Dose_Administered
# Andaman and Nicobar Islands                        216046.0
# Maharashtra                                        35040812.0
# Arunachal Pradesh                                  692475.0
# Assam                                              10495293.0
# Bihar                                              23350171.0
# Mizoram                                            654946.0
# Chhattisgarh                                       9181482.0
# Dadra and Nagar Haveli and Daman and Diu           584370.0
# Delhi                                              7835546.0
# Goa                                                1094392.0
# Gujarat                                            28101222.0
# Haryana                                            10086831.0
# Himachal Pradesh                                   4249849.0
# Jammu and Kashmir                                  5318516.0
# ...

# %%
# pie chart for first dose

dict_data={'Andaman and Nicobar Islands': 216046.0, 'Maharashtra': 35040812.0, 'Arunachal Pradesh': 692475.0, 
           'Assam': 10495293.0, 'Bihar': 23350171.0, 'Mizoram': 654946.0, 'Chhattisgarh': 9181482.0, 
           'Dadra and Nagar Haveli and Daman and Diu': 584370.0, 'Delhi': 7835546.0, 'Goa': 1094392.0,
           'Gujarat': 28101222.0, 'Haryana': 10086831.0, 'Himachal Pradesh': 4249849.0, 'Jammu and Kashmir': 5318516.0,
           'Jharkhand': 8382280.0, 'Karnataka': 25847691.0, 'Kerala': 15670747.0, 'Uttarakhand': 5070544.0, 
           'Lakshadweep': 51156.0, 'Madhya Pradesh': 29723036.0,'Ladakh': 188699.0, 'Andhra Pradesh': 17628583.0, 'Manipur': 1159424.0,
           'Rajasthan': 27008606.0,'Meghalaya': 938572.0,'West Bengal': 23257417.0, 'Chandigarh': 700285.0, 
           'Telangana': 11649268.0,'Nagaland': 632120.0, 'Odisha': 13954592.0, 'Puducherry': 601591.0,'Punjab': 8005636.0,
           'Sikkim': 497851.0, 'Tamil Nadu': 20836674.0, 'Tripura': 2411195.0, 'Uttar Pradesh': 45932488.0,  }

# Data to plot
labels = []
sizes = []
plt.figure(figsize=(15,15))

for a, b in dict_data.items():
    labels.append(a)
    sizes.append(b)

# Plot
plt.pie(sizes, labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ### c. Number of persons state wise vaccinated for second dose in India

# %%
'''c. Number of persons state wise vaccinated for Second dose in India'''

#Initiating dictionary wherein key is state name and value is Second dose administered

my_dict = {'Andaman and Nicobar Islands':94597.0};
list=['Maharashtra','Arunachal Pradesh','Assam','Bihar','Mizoram','Chhattisgarh',
      'Dadra and Nagar Haveli and Daman and Diu','Delhi','Goa','Gujarat','Haryana',
      'Himachal Pradesh','Jammu and Kashmir','Jharkhand','Karnataka','Kerala','Uttarakhand',
      'Lakshadweep','Madhya Pradesh','Andhra Pradesh','Manipur','Meghalaya','Chandigarh','Nagaland','Odisha',
      'Puducherry','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Ladakh','West Bengal']
i=0
while i<35:
   
    total=df.loc[df.State==list[i],'Second Dose Administered'].max()#----> To get number of Second  dose vaccinated people of last day of the column for perticular state
    state= list[i]
    my_dict[state]= total
    i+=1
    

print ("{:<50} {:<60}".format('State', 'Second_Dose_Administered'))
for key, value in my_dict.items():
    Second_Dose_Administered = value
    print ("{:<50} {:<60}".format( key,Second_Dose_Administered))
# Out:
# State                                              Second_Dose_Administered
# Andaman and Nicobar Islands                        94597.0
# Maharashtra                                        12112554.0
# Arunachal Pradesh                                  186619.0
# Assam                                              2208577.0
# Bihar                                              4484768.0
# Mizoram                                            206773.0
# Chhattisgarh                                       2587695.0
# Dadra and Nagar Haveli and Daman and Diu           80851.0
# Delhi                                              3000536.0
# Goa                                                302519.0
# Gujarat                                            9051153.0
# Haryana                                            2923550.0
# Himachal Pradesh                                   1382592.0
# Jammu and Kashmir                                  1489826.0
# ...

# %%
# pie-chart for second dose


dict_data={'Andaman and Nicobar Islands': 94597.0, 'Andhra Pradesh': 6214312.0, 'Arunachal Pradesh': 186619.0, 
           'Assam': 2208577.0, 'Chandigarh': 223534.0, 'Chhattisgarh': 2587695.0,
           'Dadra and Nagar Haveli and Daman and Diu': 80851.0, 'Delhi': 3000536.0, 
           'Goa': 302519.0, 'Haryana': 2923550.0, 'Gujarat': 9051153.0, 'Himachal Pradesh': 1382592.0,
           'Jammu and Kashmir': 1489826.0, 'Karnataka': 7432852.0,'Jharkhand': 1996014.0,  'Kerala': 6426984.0,
           'Ladakh': 70337.0, 'Bihar': 4484768.0, 'Lakshadweep': 17139.0, 'Madhya Pradesh': 5733640.0,
            'Manipur': 246694.0,'Maharashtra': 12112554.0, 'Meghalaya': 231982.0, 'Odisha': 4200094.0, 'Mizoram': 206773.0,
             'Tamil Nadu': 4686034.0,'Nagaland': 159388.0, 'West Bengal': 9132961.0, 'Punjab': 2285629.0,'Puducherry': 151771.0,  
           'Rajasthan': 8375056.0, 'Sikkim': 151538.0,  'Telangana': 3965624.0,
           'Tripura': 804099.0, 'Uttar Pradesh': 8515236.0, 'Uttarakhand': 1596572.0}



# Data to plot
labels = []
sizes = []
plt.figure(figsize=(15,20))

for a, b in dict_data.items():
    labels.append(a)
    sizes.append(b)

# Plot
plt.pie(sizes, labels=labels)
plt.axis('equal')
plt.show()

# %% [markdown]
# ## d. Number of Males vaccinated

# %%
#Getting last day number of male indivisuals vaccinated 

df.loc[df.State=='India','Male(Individuals Vaccinated)'].count()
# Out:
# 160

# %% [markdown]
# ## e. Number of females vaccinated

# %%
#Getting last day number of female indivisuals vaccinated 
df.loc[df.State=='India','Female(Individuals Vaccinated)'].max()
# Out:
# 115668447.0

# %% [markdown]
# ## Plotting a Bar Chart

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])
plt.figure(figsize=(10,10))        
  
if __name__ == '__main__':
    # creating data on which bar chart will be plot
    x = ["Male", "Female"]
    y = [134941971.0, 115668447.0]
      
    # making the bar chart on the data
    plt.bar(x, y)
      
    # calling the function to add value labels
    addlabels(x, y)
      
    # giving title to the plot
    plt.title("Individual vaccination")
      
    # giving X and Y labels
    plt.xlabel("Gender")
    plt.ylabel("Number of individuals")
      
    # visualizing the plot
    plt.show()

# %%
# bars representation for first dose

x = np.array(['Andaman and Nicobar Islands','Andhra Pradesh','Arunachal Pradesh','Assam','Chandigarh','Chhattisgarh',
              'Dadra and Nagar Haveli and Daman and Diu','Delhi','Goa','Haryana','Gujarat','Himachal Pradesh',
             'Jammu and Kashmir','Karnataka','Jharkhand','Kerala','Ladakh','Bihar','Lakshadweep','Madhya Pradesh',
             'Manipur','Maharashtra','Meghalaya','Odisha','Mizoram','Tamil Nadu','Nagaland','West Bengal','Punjab',
             'Puducherry','Rajasthan','Sikkim','Telangana','Tripura','Uttar Pradesh','Uttarakhand'])
y = np.array([216046.0,17628583.0,692475.0,10495293.0,700285.0,9181482.0,584370.0,7835546.0,1094392.0,10086831.0,
             28101222.0,4249849.0,5318516.0,25847691.0,8382280.0,15670747.0,188699.0,23350171.0,51156.0,29723036.0,
             1159424.0,35040812.0,938572.0,13954592.0,654946.0,20836674.0,632120.0,23257417.0,8005636.0,601591.0,
            27008606.0,497851.0,11649268.0,2411195.0,45932488.0,5070544.0])

f, ax = plt.subplots(figsize=(10,30))
plt.barh(x, y, color='green')

plt.show()

# %%
# bars representation for second dose


x = np.arraylist=(['Andaman and Nicobar Islands','Maharashtra','Arunachal Pradesh','Assam','Bihar','Mizoram','Chhattisgarh',
      'Dadra and Nagar Haveli and Daman and Diu','Delhi','Goa','Gujarat','Haryana',
      'Himachal Pradesh','Jammu and Kashmir','Jharkhand','Karnataka','Kerala','Uttarakhand',
      'Lakshadweep','Madhya Pradesh','Andhra Pradesh','Manipur','Meghalaya','Chandigarh','Nagaland','Odisha',
      'Puducherry','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Ladakh','West Bengal'])

y = np.array([94597.0,12112554.0,186619.0,2208577.0,4484768.0,206773.0,2587695.0,80851.0,3000536.0,302519.0,9051153.0,
              2923550.0, 1382592.0,1489826.0,1996014.0,7432852.0,6426984.0,1596572.0,17139.0,5733640.0,6214312.0,246694.0,
             231982.0,223534.0,159388.0,4200094.0,151771.0,2285629.0,  8375056.0,  151538.0, 4686034.0, 3965624.0,
              804099.0,8515236.0,70337.0,9132961.0,])



f, ax = plt.subplots(figsize=(10,20))


plt.barh(x, y, color='orange')



plt.show()
